# %% [markdown]
# # Handling missing values

# %% [markdown]
# ### Checking Missing values using isnull() & notnull()

# %%
#importing panadas as pd
import pandas as pd 

#importing numpy as np
import numpy as np

# Dictionary of lists
dict = {
    'First Score':[100, 90, np.nan, 95],
    'Second Score':[30, 45, 56, np.nan],
    'Third Score':[np.nan, 40, 80, 98]
       }

#creating a dataframe from list
df = pd.DataFrame(dict)


# using isnull() function
df.isnull()

#print the Dataframe
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
#importing panadas as pd
import pandas as pd 

#importing numpy as np
import numpy as np

# Dictionary of lists
dict = {
    'First Score':[100, 90, np.nan, 95],
    'Second Score':[30, 45, 56, np.nan],
    'Third Score':[np.nan, 40, 80, 98]
       }

#creating a dataframe from list
df = pd.DataFrame(dict)


# using isnull() function
df.notnull()

#print the Dataframe
df
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          NaN
# 1         90.0          45.0         40.0
# 2          NaN          56.0         80.0
# 3         95.0           NaN         98.0

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("ds1.csv")

# creating bool series true for NaN values
bool_series = pd.isnull(data["Gender"])

# filtering data
# displaying data only with Gender = NaN
data[bool_series]
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 1  940761         Ms.     Brenda              S  Robinson    NaN
#
#                       E Mail     Father's Name  Mother's Name  \
# 1  brenda.robinson@gmail.com  Raymond Robinson  Judy Robinson
#
#   Mother's Maiden Name  Salary
# 1                Perry   51063

# %%
# importing pandas package
import pandas as pd

# making data frame from csv file
data = pd.read_csv("ds1.csv")

# creating bool series true for NaN values
bool_series = pd.notnull(data["Gender"])

# filtering data
# displaying data only with Gender = NotNaN
data[bool_series]
# Out:
#     Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0   677509        Drs.       Lois              H    Walker      F
# 2   428945         Dr.        Joe              W  Robinson      M
# 3   408351        Drs.      Diane              I     Evans      F
# 4   193819         Mr.   Benjamin              R   Russell      M
# 5   499687         Mr.    Patrick              F    Bailey      M
# ..     ...         ...        ...            ...       ...    ...
# 95  639892         Mr.       Jose              K      Hill      M
# 96  704709         Dr.     Harold              Z    Nelson      M
# 97  461593         Ms.     Nicole              O      Ward      F
# 98  392491        Mrs.    Theresa              R    Murphy      F
# 99  495141        Drs.      Tammy              B     Young      F
#
#                           E Mail    Father's Name       Mother's Name  \
# 0        lois.walker@hotmail.com    Donald Walker        Helen Walker
# ...

# %%
# importing pandas as pd
import pandas as pd

# importing numpy as np
import numpy as np

# dictionary of zlists
dict = {'First Score': [100, 90, np.nan, 95],
        'Second Score': [30, 45, 56, np.nan],
        'Thirt Score': [np.nan, 40, 80, 98]}

        # creating a dataframe from lists
df = pd.DataFrame(dict)

        #using isnull() function
df.isnull()
# Out:
#    First Score  Second Score  Thirt Score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %% [markdown]
# Dropping Missing value using dropna()

# %%
import pandas as pd
import numpy as np

# dictionary of Lists
dict = {'First Score': [100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score': [53, 40, 80, 98],
        'Fourth Score': [np.nan, np.nan, np.nan, 65]}

                # creating a dataframe from lists
df = pd.DataFrame(dict)

        #using isnull() function
df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0
